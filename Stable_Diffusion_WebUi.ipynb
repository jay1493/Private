# %% [markdown]
# <a href="https://colab.research.google.com/github/jay1493/Private/blob/master/Stable_Diffusion_WebUi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================
# 1. Mount Google Drive
# ==============================
from google.colab import drive
drive.mount('/content/drive')

# ==============================
# 2. Set permanent paths in Drive
# ==============================
WEBUI_PATH = "/content/drive/MyDrive/stable-diffusion-webui"
MODEL_PATH = f"{WEBUI_PATH}/models/Stable-diffusion"
LORA_PATH = f"{WEBUI_PATH}/models/Lora"
VAE_PATH = f"{WEBUI_PATH}/models/VAE"
OUTPUTS_PATH = f"{WEBUI_PATH}/outputs"
TRAINING_PATH = f"{WEBUI_PATH}/training_data"

# ==============================
# 3. Ensure WebUI exists in Drive
# ==============================
import os
if not os.path.exists(WEBUI_PATH):
    # %cd /content/drive/MyDrive
    # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
else:
    print("✅ WebUI already exists in Drive")

# ==============================
# 4. Ensure required folders exist
# ==============================
# !mkdir -p "$MODEL_PATH" "$LORA_PATH" "$VAE_PATH" "$OUTPUTS_PATH" "$TRAINING_PATH"

# ==============================
# 4b. Download a realistic base model if not exists
# ==============================
REALVIS_URL="https://huggingface.co/SG161222/RealVisXL_V4.0/resolve/main/RealVisXL_V4.0.safetensors"
REALVIS_PATH=f"{MODEL_PATH}/RealVisXL_V4.0.safetensors"

if not os.path.exists(REALVIS_PATH):
    print("⬇️ Downloading RealVisXL base model...")
    # !wget -O "$REALVIS_PATH" "$REALVIS_URL"
else:
    print("✅ RealVisXL model already exists")

# ==============================
# 5. Link WebUI from Drive into Colab
# ==============================
if not os.path.exists("/content/stable-diffusion-webui"):
    # !ln -s "$WEBUI_PATH" /content/stable-diffusion-webui

# ==============================
# 6. Launch WebUI (all outputs saved directly in Drive)
# ==============================
# %cd /content/stable-diffusion-webui
# !python launch.py --share --skip-torch-cuda-test
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ WebUI already exists in Drive
# ⬇️ Downloading RealVisXL base model...
# --2025-08-30 14:40:52--  https://huggingface.co/SG161222/RealVisXL_V4.0/resolve/main/RealVisXL_V4.0.safetensors
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.118, 18.164.174.17, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
